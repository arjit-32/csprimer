# %%
import os
from PIL import Image

# Input folder (read from here)
input_folder = r"C:\Users\SharmaArj\OneDrive - Informa plc\Pictures\Screenshots"

# Output folder (save WebP files here)
output_folder = r"C:\converted_images"

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.lower().endswith(".png"):
        file_path = os.path.join(input_folder, filename)
        try:
            with Image.open(file_path).convert("RGB") as img:
                new_filename = os.path.splitext(filename)[0] + ".webp"
                new_file_path = os.path.join(output_folder, new_filename)
                
                img.save(new_file_path, "WEBP")
                print(f"✅ Converted: {filename} → {new_filename}")
        except Exception as e:
            print(f"❌ Failed to convert {filename}: {e}")
# Out:
# ✅ Converted: consistent-hashing.png → consistent-hashing.webp
# ✅ Converted: hash-based-load-balancing.png → hash-based-load-balancing.webp
# ✅ Converted: n-tier.png → n-tier.webp
